# %%
import zipfile
import os
import pandas as pd
import glob

# Step 1: Extract the Zip File
zip_file_path = 'Property_data.zip'  # Replace with your zip file's path
extraction_path = 'Property_data/Property_data'  # Directory where files will be extracted

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

print("Zip file extracted successfully.")

# Step 2: Check if CSV Files Are Present
csv_files_path = os.path.join(extraction_path, '*.csv')

# Get a list of all CSV file paths
csv_files = glob.glob(csv_files_path)

# Debug: Check how many CSV files were found
print(f"Found {len(csv_files)} CSV files at {csv_files_path}.")
if len(csv_files) == 0:
    print("No CSV files found. Please check the extraction path and zip file contents.")
else:
    # Step 3: List Extracted Files (Debugging)
    extracted_files = os.listdir(extraction_path)
    print(f"Files extracted: {extracted_files}")

    # Step 4: Merge All CSV Files
    dataframes = []  # Initialize an empty list to store DataFrames

    # Loop through each CSV file and append to the list
    for file in csv_files:
        try:
            # Try reading the file with a different encoding to avoid issues like 'ÿþ'
            df = pd.read_csv(file, encoding='unicode_escape')  # Fallback encoding
            print(f"File: {file}, Shape: {df.shape}")
            print(f"Columns in {file}: {df.columns.tolist()}")

            # Check if the necessary 'property_id' column exists before appending
            if 'property_id' in df.columns:
                dataframes.append(df)
            else:
                print(f"'property_id' column NOT found in {file}")

        except Exception as e:
            print(f"Error reading {file}: {e}")

    # Step 5: Concatenate all DataFrames into one
    if len(dataframes) > 0:
        merged_data = pd.concat(dataframes, ignore_index=True)

        # Step 6: Clean and Standardize the Data
        merged_data.drop_duplicates(inplace=True)  # Drop duplicates

        # Handle missing values (fill with default values)
        merged_data.fillna({
            'property_id': 'Unknown',
            'type': 'Unknown',
            'activation_date': 'Unknown',
            'bathroom': 0,
            'floor': 0,
            'total_floor': 0,
            'furnishing': 'Unknown',
            'gym': 0,
            'latitude': 0,
            'longitude': 0,
            'lease_type': 'Unknown',
            'lift': 0,
            'locality': 'Unknown',
            'parking': 'Unknown',
            'property_age': 0,
            'property_size': 0,
            'swimming_pool': 0,
            'pin_code': 'Unknown',
            'rent': 0,
            'deposit': 0,
            'building_type': 'Unknown',
            'location': 'Unknown'
        }, inplace=True)

        # Remove unwanted columns like the one starting with 'ÿþ'
        merged_data = merged_data.loc[:, ~merged_data.columns.str.contains('ÿþ')]

        # Step 7: Save the Merged Data
        output_file = 'merged_property_data.csv'
        merged_data.to_csv(output_file, index=False)
        print(f"Merged data saved to {output_file}")

        # Step 8: Print Final Data Information
        print(f"Final merged data contains {merged_data.shape[0]} rows and {merged_data.shape[1]} columns.")
        print("Missing values in each column:")
        print(merged_data.isnull().sum())
    else:
        print("No data loaded from CSV files.")

# Step 9: Define file path and load cleaned data
input_dir = "Property_data/Property_data"  # Replace with your actual directory path
output_dir = "Property_data/outputs"  # Replace with your desired output directory

# Step 10: Load the cleaned merged data
merged_data = pd.read_csv("Property_data/outputs/cleaned_merged_property_data_with_imputation.csv")

# Remove the unwanted 'Unnamed' column if it exists
merged_data = merged_data.loc[:, ~merged_data.columns.str.contains('^Unnamed')]

# Step 11: Load the photos.tsv file containing 'property_id' and 'photo_urls'
photos_file_path = "property_photos.tsv"  # Adjust the path if needed
try:
    photos_df = pd.read_csv(photos_file_path, sep='\t')  # Assuming it's a TSV file
    print(f"Photos data loaded successfully from {photos_file_path}.")
except Exception as e:
    print(f"Error loading photos data: {e}")

# Check if the 'photo_urls' column exists in photos_df
if 'photo_urls' in photos_df.columns:
    # Step 12: Create photo_count feature
    photos_df['photo_count'] = photos_df['photo_urls'].apply(lambda x: len(str(x).split(',')) if pd.notnull(x) else 0)
    print("Photo count feature created successfully.")
else:
    print("'photo_urls' column not found in the Property_photos dataset.")

# Step 13: Merge the photos_df with merged_data on 'property_id'
merged_data = merged_data.merge(photos_df[['property_id', 'photo_count']], on='property_id', how='left')

# Step 14: Load the property_interactions dataset
interactions_file_path = "property_interactions.csv"  # Adjust the path if needed
try:
    interactions_df = pd.read_csv(interactions_file_path)
    print(f"Interactions data loaded successfully from {interactions_file_path}.")
except Exception as e:
    print(f"Error loading interactions data: {e}")

# Step 15: Calculate total_interactions for each property
total_interactions = interactions_df.groupby('property_id').size().reset_index(name='total_interactions')

# Step 16: Merge the total_interactions with the merged_data
merged_data = merged_data.merge(total_interactions, on='property_id', how='left')

# Step 17: Save the updated data with the new features
output_file = "Property_data/outputs/cleaned_property_data_with_features.csv"
merged_data.to_csv(output_file, index=False)

# Step 18: Print the updated dataset information
print(f"Data with new features ('photo_count', 'total_interactions') has been saved to '{output_file}'.")
print(f"Final data contains {merged_data.shape[0]} rows and {merged_data.shape[1]} columns.")
print("Missing values after feature engineering:")
print(merged_data.isnull().sum())
# Out:
# Zip file extracted successfully.
# Found 64 CSV files at Property_data/Property_data\*.csv.
# Files extracted: ['Akshayanagar.csv', 'Arekere.csv', 'Banashankari.csv', 'Basavanagudi.csv', 'Basaveshwar Nagar.csv', 'Begur.csv', 'Bellandur.csv', 'Bilekahalli.csv', 'Bommanahalli.csv', 'Brookefield.csv', 'BTM 2nd Stage.csv', 'BTM_Layout.csv', 'Chikkalasandra.csv', 'Doddanekundi.csv', 'Ejipura.csv', 'Electronic City.csv', 'Electronics City Phase 1.csv', 'Gottigere.csv', 'HBR Layout.csv', 'Hebbal.csv', 'Hongasandra.csv', 'Hoodi.csv', 'Horamavu.csv', 'Hosakerehalli.csv', 'HSR_Layout.csv', 'Hulimavu.csv', 'Indiranagar.csv', 'Jayanagar.csv', 'JP Nagar.csv', 'K.R Puram.csv', 'Kadugodi.csv', 'Kaggadasapura.csv', 'Kalyan Nagar.csv', 'Kammanahalli.csv', 'Kasavanahalli.csv', 'Kengeri Satellite Town.csv', 'Kengeri.csv', 'Konanakunte.csv', 'Koramangala.csv', 'Krishnarajapura.csv', 'Kumaraswamy Layout.csv', 'Lingarajapuram.csv', 'Mahadevapura.csv', 'Marathahalli.csv', 'Mathikere.csv', 'Munnekollal.csv', 'Nagarbhavi.csv', 'Padmanabhanagar.csv', 'Property_data', 'Raja Rajeshwari Nagar.csv', 'Rajaji Nagar.csv', 'Ramamurthy Nagar.csv', 'RR Nagar.csv', 'RT Nagar.csv', 'Singasandra.csv', 'Subramanyapura.csv', 'Sunkadakatte.csv', 'Thanisandra.csv', 'Uttarahalli Hobli.csv', 'Varthur.csv', 'Vidyaranyapura.csv', 'Vijaya Nagar.csv', 'Whitefield.csv', 'Yelahanka New Town.csv', 'Yelahanka.csv']
# File: Property_data/Property_data\Akshayanagar.csv, Shape: (144, 21)
# Columns in Property_data/Property_data\Akshayanagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Arekere.csv, Shape: (161, 21)
# Columns in Property_data/Property_data\Arekere.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Banashankari.csv, Shape: (487, 21)
# Columns in Property_data/Property_data\Banashankari.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Basavanagudi.csv, Shape: (125, 21)
# Columns in Property_data/Property_data\Basavanagudi.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Basaveshwar Nagar.csv, Shape: (176, 21)
# Columns in Property_data/Property_data\Basaveshwar Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Begur.csv, Shape: (155, 21)
# Columns in Property_data/Property_data\Begur.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Bellandur.csv, Shape: (313, 21)
# Columns in Property_data/Property_data\Bellandur.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Bilekahalli.csv, Shape: (210, 21)
# Columns in Property_data/Property_data\Bilekahalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Bommanahalli.csv, Shape: (224, 21)
# Columns in Property_data/Property_data\Bommanahalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'location', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Brookefield.csv, Shape: (138, 21)
# Columns in Property_data/Property_data\Brookefield.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\BTM 2nd Stage.csv, Shape: (215, 21)
# Columns in Property_data/Property_data\BTM 2nd Stage.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\BTM_Layout.csv, Shape: (410, 21)
# Columns in Property_data/Property_data\BTM_Layout.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Chikkalasandra.csv, Shape: (129, 21)
# Columns in Property_data/Property_data\Chikkalasandra.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Doddanekundi.csv, Shape: (105, 21)
# Columns in Property_data/Property_data\Doddanekundi.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Ejipura.csv, Shape: (166, 21)
# Columns in Property_data/Property_data\Ejipura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Electronic City.csv, Shape: (630, 21)
# Columns in Property_data/Property_data\Electronic City.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Electronics City Phase 1.csv, Shape: (132, 21)
# Columns in Property_data/Property_data\Electronics City Phase 1.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Gottigere.csv, Shape: (143, 21)
# Columns in Property_data/Property_data\Gottigere.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\HBR Layout.csv, Shape: (171, 21)
# Columns in Property_data/Property_data\HBR Layout.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Hebbal.csv, Shape: (189, 21)
# Columns in Property_data/Property_data\Hebbal.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Hongasandra.csv, Shape: (156, 21)
# Columns in Property_data/Property_data\Hongasandra.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Hoodi.csv, Shape: (166, 21)
# Columns in Property_data/Property_data\Hoodi.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Horamavu.csv, Shape: (233, 21)
# Columns in Property_data/Property_data\Horamavu.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Hosakerehalli.csv, Shape: (145, 21)
# Columns in Property_data/Property_data\Hosakerehalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\HSR_Layout.csv, Shape: (862, 1)
# Columns in Property_data/Property_data\HSR_Layout.csv: ['ÿþ']
# 'property_id' column NOT found in Property_data/Property_data\HSR_Layout.csv
# File: Property_data/Property_data\Hulimavu.csv, Shape: (206, 21)
# Columns in Property_data/Property_data\Hulimavu.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Indiranagar.csv, Shape: (123, 21)
# Columns in Property_data/Property_data\Indiranagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Jayanagar.csv, Shape: (143, 21)
# Columns in Property_data/Property_data\Jayanagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\JP Nagar.csv, Shape: (655, 21)
# Columns in Property_data/Property_data\JP Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\K.R Puram.csv, Shape: (118, 21)
# Columns in Property_data/Property_data\K.R Puram.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kadugodi.csv, Shape: (148, 21)
# Columns in Property_data/Property_data\Kadugodi.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kaggadasapura.csv, Shape: (155, 21)
# Columns in Property_data/Property_data\Kaggadasapura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kalyan Nagar.csv, Shape: (121, 21)
# Columns in Property_data/Property_data\Kalyan Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kammanahalli.csv, Shape: (144, 21)
# Columns in Property_data/Property_data\Kammanahalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kasavanahalli.csv, Shape: (136, 21)
# Columns in Property_data/Property_data\Kasavanahalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kengeri Satellite Town.csv, Shape: (176, 21)
# Columns in Property_data/Property_data\Kengeri Satellite Town.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kengeri.csv, Shape: (99, 21)
# Columns in Property_data/Property_data\Kengeri.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Konanakunte.csv, Shape: (121, 21)
# Columns in Property_data/Property_data\Konanakunte.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Koramangala.csv, Shape: (235, 1)
# Columns in Property_data/Property_data\Koramangala.csv: ['property_id/type/activation_date/bathroom/floor/total_floor/furnishing/gym/latitude/longitude/lease_type/lift/locality/parking/property_age/property_size/swimming_pool/pin_code/rent/deposit/building_type']
# 'property_id' column NOT found in Property_data/Property_data\Koramangala.csv
# File: Property_data/Property_data\Krishnarajapura.csv, Shape: (258, 21)
# Columns in Property_data/Property_data\Krishnarajapura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Kumaraswamy Layout.csv, Shape: (329, 21)
# Columns in Property_data/Property_data\Kumaraswamy Layout.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Lingarajapuram.csv, Shape: (102, 21)
# Columns in Property_data/Property_data\Lingarajapuram.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Mahadevapura.csv, Shape: (278, 21)
# Columns in Property_data/Property_data\Mahadevapura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Marathahalli.csv, Shape: (494, 21)
# Columns in Property_data/Property_data\Marathahalli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Mathikere.csv, Shape: (171, 21)
# Columns in Property_data/Property_data\Mathikere.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Munnekollal.csv, Shape: (177, 21)
# Columns in Property_data/Property_data\Munnekollal.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Nagarbhavi.csv, Shape: (225, 21)
# Columns in Property_data/Property_data\Nagarbhavi.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Padmanabhanagar.csv, Shape: (137, 21)
# Columns in Property_data/Property_data\Padmanabhanagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Raja Rajeshwari Nagar.csv, Shape: (111, 21)
# Columns in Property_data/Property_data\Raja Rajeshwari Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Rajaji Nagar.csv, Shape: (203, 21)
# Columns in Property_data/Property_data\Rajaji Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Ramamurthy Nagar.csv, Shape: (522, 21)
# Columns in Property_data/Property_data\Ramamurthy Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\RR Nagar.csv, Shape: (274, 21)
# Columns in Property_data/Property_data\RR Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\RT Nagar.csv, Shape: (192, 21)
# Columns in Property_data/Property_data\RT Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Singasandra.csv, Shape: (141, 21)
# Columns in Property_data/Property_data\Singasandra.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Subramanyapura.csv, Shape: (104, 21)
# Columns in Property_data/Property_data\Subramanyapura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Sunkadakatte.csv, Shape: (128, 21)
# Columns in Property_data/Property_data\Sunkadakatte.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Thanisandra.csv, Shape: (138, 21)
# Columns in Property_data/Property_data\Thanisandra.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Uttarahalli Hobli.csv, Shape: (182, 21)
# Columns in Property_data/Property_data\Uttarahalli Hobli.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Varthur.csv, Shape: (130, 21)
# Columns in Property_data/Property_data\Varthur.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Vidyaranyapura.csv, Shape: (207, 21)
# Columns in Property_data/Property_data\Vidyaranyapura.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Vijaya Nagar.csv, Shape: (190, 21)
# Columns in Property_data/Property_data\Vijaya Nagar.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Whitefield.csv, Shape: (745, 21)
# Columns in Property_data/Property_data\Whitefield.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Yelahanka New Town.csv, Shape: (186, 21)
# Columns in Property_data/Property_data\Yelahanka New Town.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# File: Property_data/Property_data\Yelahanka.csv, Shape: (343, 21)
# Columns in Property_data/Property_data\Yelahanka.csv: ['property_id', 'type', 'activation_date', 'bathroom', 'floor', 'total_floor', 'furnishing', 'gym', 'latitude', 'longitude', 'lease_type', 'lift', 'locality', 'parking', 'property_age', 'property_size', 'swimming_pool', 'pin_code', 'rent', 'deposit', 'building_type']
# Merged data saved to merged_property_data.csv
# Final merged data contains 13435 rows and 22 columns.
# Missing values in each column:
# property_id        0
# type               0
# activation_date    0
# bathroom           0
# floor              0
# total_floor        0
# furnishing         0
# gym                0
# latitude           0
# longitude          0
# lease_type         0
# lift               0
# locality           0
# parking            0
# property_age       0
# property_size      0
# swimming_pool      0
# pin_code           0
# rent               0
# deposit            0
# building_type      0
# location           0
# dtype: int64
# Photos data loaded successfully from property_photos.tsv.
# Photo count feature created successfully.
# Interactions data loaded successfully from property_interactions.csv.
# Data with new features ('photo_count', 'total_interactions') has been saved to 'Property_data/outputs/cleaned_property_data_with_features.csv'.
# Final data contains 224 rows and 24 columns.
# Missing values after feature engineering:
# property_id            0
# type                   0
# activation_date        0
# bathroom               0
# floor                  0
# total_floor            0
# furnishing             0
# gym                    0
# latitude               0
# longitude              0
# lease_type             0
# lift                   0
# locality               0
# parking                0
# property_age           0
# property_size          0
# swimming_pool          0
# pin_code               0
# rent                   0
# deposit                0
# building_type          0
# location               0
# photo_count            0
# total_interactions    46
# dtype: int64
